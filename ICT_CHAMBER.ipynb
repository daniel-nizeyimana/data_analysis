# %% [markdown]
# <!-- INSTALL LIBRARY pandas,matplotlib,Numpy -->

# %%
# just to load the dataset
import pandas as pd
ICT_CHAMBER=pd.read_csv("C:\\Users\\PC\\Desktop\\sample_sentiment_data.csv")
pd.read_csv("C:\\Users\\PC\\Desktop\\sample_sentiment_data.csv")
# Out:
#          date                                 text
# 0  2025-05-01                       Great service!
# 1  2025-05-02            Not happy with the delay.
# 2  2025-05-03          Amazing product experience.
# 3  2025-05-04                     Service was slow
# 4  2025-05-05                    Very disappointed
# 5  2025-05-06                Awesome support team.
# 6  2025-05-07          Confusing fare calculation.
# 7  2025-05-08  Transparent pricing is appreciated.
# 8  2025-05-09         It's unfair for short trips.
# 9  2025-05-10         Much better than flat rates.

# %%
# checking the missing value
ICT_CHAMBER.isna().sum()
# Out:
# date    0
# text    0
# dtype: int64

# %%
# checking the number of column
ICT_CHAMBER.columns
# Out:
# Index(['date', 'text'], dtype='object')

# %%
# cheking duplication
ICT_CHAMBER.duplicated
# Out:
# <bound method DataFrame.duplicated of          date                                 text
# 0  2025-05-01                       Great service!
# 1  2025-05-02            Not happy with the delay.
# 2  2025-05-03          Amazing product experience.
# 3  2025-05-04                     Service was slow
# 4  2025-05-05                    Very disappointed
# 5  2025-05-06                Awesome support team.
# 6  2025-05-07          Confusing fare calculation.
# 7  2025-05-08  Transparent pricing is appreciated.
# 8  2025-05-09         It's unfair for short trips.
# 9  2025-05-10         Much better than flat rates.>

# %%
ICT_CHAMBER.duplicated().sum()
# Out:
# 0

# %%
# create general report
from ydata_profiling import ProfileReport
profile=ProfileReport(ICT_CHAMBER)
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;YData Profiling vv4.14.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2025-05-17 06:42:48.101796&quot;&gt;&lt;title&gt;YData Profiling Report&lt;/title&gt;&lt;style&gt;
# @charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...

# %%
 # VISULIZATION ON DIFFERENCE CHARTS // this is line chart
import plotly.express as px
fig=px.line(ICT_CHAMBER,x='text',y='date')
fig.update_layout(paper_bgcolor="brown")
fig.update_layout(xaxis=dict(showgrid=True,gridcolor='red'))
fig.update_layout(yaxis=dict(showgrid=True,gridcolor='brown'))
fig.update_layout(font=dict(color='blue'))
fig.show()

# %%
# this is visualization by Bar chart
fig=px.bar(ICT_CHAMBER,x='text',y='date')
fig.update_layout(plot_bgcolor='cyan')
fig.update_layout(xaxis=dict(showgrid=True,gridcolor='red'))
fig.update_layout(yaxis=dict(showgrid=True,gridcolor='brown'))
fig.show()

# %%
ICT_CHAMBER['date'] = pd.to_datetime(ICT_CHAMBER['date'])

# %%
filtered = ICT_CHAMBER[ICT_CHAMBER['date'] == '2025-05-10']

# %%
start_date = '2025-05-01'
end_date = '2025-05-03'

filtered = ICT_CHAMBER[(ICT_CHAMBER['date'] >= start_date) & (ICT_CHAMBER['date'] <= end_date)]

# %%
# Filter by May 2025 only
filtered = ICT_CHAMBER[ICT_CHAMBER['date'].dt.month == 5]

# %%
pd.read_csv("C:\\Users\\PC\\Desktop\\sample_sentiment_data.csv")
# Out:
#          date                                 text
# 0  2025-05-01                       Great service!
# 1  2025-05-02            Not happy with the delay.
# 2  2025-05-03          Amazing product experience.
# 3  2025-05-04                     Service was slow
# 4  2025-05-05                    Very disappointed
# 5  2025-05-06                Awesome support team.
# 6  2025-05-07          Confusing fare calculation.
# 7  2025-05-08  Transparent pricing is appreciated.
# 8  2025-05-09         It's unfair for short trips.
# 9  2025-05-10         Much better than flat rates.

# %%
# Ensure datetime format
ICT_CHAMBER['date'] = pd.to_datetime(ICT_CHAMBER['date'])

# Filter for May 1, 2025
may1_df = ICT_CHAMBER[ICT_CHAMBER['date'] == '2025-05-01']

# %%
# this is visualization by scatter chart
import plotly.express as px
fig=px.scatter(ICT_CHAMBER,x='text',y='date')
fig.update_layout(plot_bgcolor='cyan')
fig.update_layout(xaxis=dict(showgrid=True,gridcolor='red'))
fig.update_layout(yaxis=dict(showgrid=True,gridcolor='brown'))
fig.update_layout(font=dict(color='green'))
fig.show()
