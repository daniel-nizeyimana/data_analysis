# %%
import pandas as pd
myinfo_data=pd.read_excel("C:\\Users\\PC\\Desktop\\myinfo.xlsx")

# %%
pd.read_excel("C:\\Users\\PC\\Desktop\\myinfo.xlsx")
# Out:
#                 NAMES  AGE   ADDRESS  MARKS
# 0    MUVUNYI Innocent   23   KAMONYI   40.0
# 1       IRAKOZE Grace   21  KICUKIRO   70.0
# 2       MUTONI Yvette   19   GATSIBO    NaN
# 3    NIYIMUBONA Simon   32    KIREHE   31.0
# 4      MWEZI Pierrine   54    RUBAVU    NaN
# 5          RURANGIRWA   12   KAMONYI   70.0
# 6  Felix NZAMWITAKUZE   26       NaN    NaN
# 7   Daniel NIZEYIMANA   21   GATSIBO   80.0

# %%
from ydata_profiling import ProfileReport
profile=ProfileReport(myinfo_data)
profile
# Out:
#             <div>
#                 <ins><a href="ttps://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# ...

# %%
myinfo_data.isna().sum()
# Out:
# NAMES      0
# AGE        0
# ADDRESS    1
# MARKS      3
# dtype: int64

# %%
pd.read_excel("C:\\Users\\PC\\Desktop\\myinfo.xlsx")
# Out:
#                 NAMES  AGE   ADDRESS  MARKS
# 0    MUVUNYI Innocent   23   KAMONYI   40.0
# 1       IRAKOZE Grace   21  KICUKIRO   70.0
# 2       MUTONI Yvette   19   GATSIBO    NaN
# 3    NIYIMUBONA Simon   32    KIREHE   31.0
# 4      MWEZI Pierrine   54    RUBAVU    NaN
# 5          RURANGIRWA   12   KAMONYI   70.0
# 6  Felix NZAMWITAKUZE   26       NaN    NaN
# 7   Daniel NIZEYIMANA   21   GATSIBO   80.0

# %%
import numpy as np
import matplotlib as plt
import plotly.express as px

# %%
myinfo_data=pd.read_excel("C:\\Users\\PC\\Desktop\\myinfo1.xlsx")

# %%
myinfo_data.columns
# Out:
# Index(['NAMES', 'AGE', 'ADDRESS', 'MARKS'], dtype='object')

# %%
fig = px.line(myinfo_data, x="NAMES", y="MARKS")
fig.show()

# %%
fig = px.bar(myinfo_data, x="NAMES",y="MARKS")
fig.update_layout(plot_bgcolor='yellow')
fig.update_layout(paper_bgcolor='green')

fig.show()

# %%
fig=px.scatter(myinfo_data,x="ADDRESS",y="MARKS")
fig.update_layout(plot_bgcolor='blue')
fig.update_layout(paper_bgcolor='red')
fig.show()

# %%
import pandas as pd
import plotly.express as px

# Load data
df = pd.read_excel('myinfo1.xlsx')

# Create Pie Chart
fig = px.pie(df, values="MARKS", names="NAMES", color="NAMES",hover_data=["MARKS"])  # Removed textinfo


# Show plot
fig.show()

# %%
fig.write_image("pie.png")
print("Chart saved successfully as 'pie_chart.png'!")
# Out:
# Chart saved successfully as 'pie_chart.png'!

# %%
from ydata_profiling import ProfileReport
profile=ProfileReport(myinfo_data)
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;YData Profiling vv4.14.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2025-04-21 21:51:26.804645&quot;&gt;&lt;title&gt;YData Profiling Report&lt;/title&gt;&lt;style&gt;
# @charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...

# %%
myinfo_data.isna().sum()
# Out:
# NAMES      0
# AGE        0
# ADDRESS    1
# MARKS      3
# dtype: int64

# %%
myinfo_data["ADDRESS"]=myinfo_data["ADDRESS"].ffill()

# %%
print(myinfo_data)
# Out:
#                 NAMES  AGE   ADDRESS  MARKS
# 0    MUVUNYI Innocent   23   KAMONYI   40.0
# 1       IRAKOZE Grace   21  KICUKIRO   70.0
# 2       MUTONI Yvette   19   GATSIBO    NaN
# 3    NIYIMUBONA Simon   32    KIREHE   31.0
# 4      MWEZI Pierrine   54    RUBAVU    NaN
# 5          RURANGIRWA   12   KAMONYI   70.0
# 6  Felix NZAMWITAKUZE   26   KAMONYI    NaN
# 7   Daniel NIZEYIMANA   21   GATSIBO   80.0

# %%
myinfo_data["MARKS"]=myinfo_data["MARKS"].bfill()
print(myinfo_data)
# Out:
#                 NAMES  AGE   ADDRESS  MARKS
# 0    MUVUNYI Innocent   23   KAMONYI   40.0
# 1       IRAKOZE Grace   21  KICUKIRO   70.0
# 2       MUTONI Yvette   19   GATSIBO   31.0
# 3    NIYIMUBONA Simon   32    KIREHE   31.0
# 4      MWEZI Pierrine   54    RUBAVU   70.0
# 5          RURANGIRWA   12   KAMONYI   70.0
# 6  Felix NZAMWITAKUZE   26   KAMONYI   80.0
# 7   Daniel NIZEYIMANA   21   GATSIBO   80.0

# %%
myinfo_data.iloc()

# %%
import pandas as pd

# %%
myinfo_data.iloc()

# %%
myinfo_data[:3]
# Out:
#               NAMES  AGE   ADDRESS  MARKS
# 0  MUVUNYI Innocent   23   KAMONYI   40.0
# 1     IRAKOZE Grace   21  KICUKIRO   70.0
# 2     MUTONI Yvette   19   GATSIBO   31.0

# %%
myinfo_data[6:]
# Out:
#                 NAMES  AGE  ADDRESS  MARKS
# 6  Felix NZAMWITAKUZE   26  KAMONYI   80.0
# 7   Daniel NIZEYIMANA   21  GATSIBO   80.0

# %%
myinfo_data[3:5]
# Out:
#               NAMES  AGE ADDRESS  MARKS
# 3  NIYIMUBONA Simon   32  KIREHE   31.0
# 4    MWEZI Pierrine   54  RUBAVU   70.0

# %%
import pandas as pd

# %%
pd.read_excel("C:\\Users\\PC\\Desktop\\myinfo.xlsx")
# Out:
#                 NAMES  AGE   ADDRESS  MARKS
# 0    MUVUNYI Innocent   23   KAMONYI   40.0
# 1       IRAKOZE Grace   21  KICUKIRO   70.0
# 2       MUTONI Yvette   19   GATSIBO    NaN
# 3    NIYIMUBONA Simon   32    KIREHE   31.0
# 4      MWEZI Pierrine   54    RUBAVU    NaN
# 5          RURANGIRWA   12   KAMONYI   70.0
# 6  Felix NZAMWITAKUZE   26       NaN    NaN
# 7   Daniel NIZEYIMANA   21   GATSIBO   80.0

# %%
myinfo_data=pd.read_excel("C:\\Users\\PC\\Desktop\\myinfo.xlsx")

# %%
myinfo_data.head(2)
# Out:
#               NAMES  AGE   ADDRESS  MARKS
# 0  MUVUNYI Innocent   23   KAMONYI   40.0
# 1     IRAKOZE Grace   21  KICUKIRO   70.0

# %%
myinfo_data.isna().sum()
# Out:
# NAMES      0
# AGE        0
# ADDRESS    1
# MARKS      3
# dtype: int64

# %%
myinfo_data.duplicated().sum()
# Out:
# 0

# %%
myinfo_data.columns
# Out:
# Index(['NAMES', 'AGE', 'ADDRESS', 'MARKS'], dtype='object')

# %%
from ydata_profiling import ProfileReport
profile=ProfileReport(myinfo_data)
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;YData Profiling vv4.14.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2025-04-21 21:51:39.227438&quot;&gt;&lt;title&gt;YData Profiling Report&lt;/title&gt;&lt;style&gt;
# @charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...

# %%
myinfo_data["ADDRESS"]=myinfo_data["ADDRESS"].ffill()

# %%
pd.read_excel("C:\\Users\\PC\\Desktop\\myinfo.xlsx")
# Out:
#                 NAMES  AGE   ADDRESS  MARKS
# 0    MUVUNYI Innocent   23   KAMONYI   40.0
# 1       IRAKOZE Grace   21  KICUKIRO   70.0
# 2       MUTONI Yvette   19   GATSIBO    NaN
# 3    NIYIMUBONA Simon   32    KIREHE   31.0
# 4      MWEZI Pierrine   54    RUBAVU    NaN
# 5          RURANGIRWA   12   KAMONYI   70.0
# 6  Felix NZAMWITAKUZE   26       NaN    NaN
# 7   Daniel NIZEYIMANA   21   GATSIBO   80.0

# %%
print(myinfo_data)
# Out:
#                 NAMES  AGE   ADDRESS  MARKS
# 0    MUVUNYI Innocent   23   KAMONYI   40.0
# 1       IRAKOZE Grace   21  KICUKIRO   70.0
# 2       MUTONI Yvette   19   GATSIBO    NaN
# 3    NIYIMUBONA Simon   32    KIREHE   31.0
# 4      MWEZI Pierrine   54    RUBAVU    NaN
# 5          RURANGIRWA   12   KAMONYI   70.0
# 6  Felix NZAMWITAKUZE   26   KAMONYI    NaN
# 7   Daniel NIZEYIMANA   21   GATSIBO   80.0

# %%
myinfo_data.dtypes
# Out:
# NAMES       object
# AGE          int64
# ADDRESS     object
# MARKS      float64
# dtype: object

# %%
import plotly.express as px
import pandas as pd
fig=px.bar(myinfo_data,x="NAMES",y="MARKS")
fig.show()

# %%
import matplotlib.pyplot as plt

# %%
date=["20/12","27/12","30/12"]
temp=[8.7,6.1,10.9]
plt.plot(date,temp)
plt.grid(True,color="red")
plt.title("performance of temperature vs date")
plt.xlabel("Date")
plt.ylabel("Temperature")
plt.show()
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_14128\788095289.py:8: UserWarning:
#
# FigureCanvasAgg is non-interactive, and thus cannot be shown

# %%
import pandas as pd
import numpy as np

# %%
pd.read_excel("C:\\Users\\PC\\Desktop\\myinfo.xlsx")
# Out:
#                 NAMES  AGE   ADDRESS  MARKS
# 0    MUVUNYI Innocent   23   KAMONYI   40.0
# 1       IRAKOZE Grace   21  KICUKIRO   70.0
# 2       MUTONI Yvette   19   GATSIBO    NaN
# 3    NIYIMUBONA Simon   32    KIREHE   31.0
# 4      MWEZI Pierrine   54    RUBAVU    NaN
# 5          RURANGIRWA   12   KAMONYI   70.0
# 6  Felix NZAMWITAKUZE   26       NaN    NaN
# 7   Daniel NIZEYIMANA   21   GATSIBO   80.0

# %%
myinfo_data=pd.read_excel("C:\\Users\\PC\\Desktop\\myinfo.xlsx")
myinfo_data.isna().sum()
# Out:
# NAMES      0
# AGE        0
# ADDRESS    1
# MARKS      3
# dtype: int64

# %%
myinfo_data.columns
# Out:
# Index(['NAMES', 'AGE', 'ADDRESS', 'MARKS'], dtype='object')

# %%
myinfo_data.shape
# Out:
# (8, 4)

# %%
myinfo_data.iloc[3:5]
# Out:
#               NAMES  AGE ADDRESS  MARKS
# 3  NIYIMUBONA Simon   32  KIREHE   31.0
# 4    MWEZI Pierrine   54  RUBAVU    NaN

# %%
myinfo_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   NAMES    8 non-null      object
#  1   AGE      8 non-null      int64
#  2   ADDRESS  7 non-null      object
#  3   MARKS    5 non-null      float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 388.0+ bytes

# %%
import pandas as pd 
pd.read_excel("C:\\Users\\PC\\Desktop\\MARKS FOR II TERM ALL CLASSES.xlsx")
# Out:
#     N0                    NAMES  QUIZ1/10
# 0    1        BIHOYIKI Jeanette      10.0
# 1    2        DUSHIMIMANA Bruce       8.0
# 2    3            GISUBIZO Remy       1.0
# 3    4      HAGENIMANA Patience      10.0
# 4    5            ISHIMWE Diane      10.0
# 5    6            ISHIMWE Margo      10.0
# 6    7           ISHIMWE Soline      10.0
# 7    8       MANISHIMWE Fabiola       8.0
# 8    9          MUGISHA Gervais       8.0
# 9   10          MUHOZA Joselyne      10.0
# 10  11    MUSHIKIWABO Slylivier       2.0
# 11  12  MUSHIMIYIMANA Pascaline      10.0
# 12  13    NIYIKIZA UWASE Chania      10.0
# 13  14        NIYITANGA Gilbert      10.0
# 14  15      NIYOGISUBIZO Daniel       1.0
# 15  16  NIYOGISUBIZO JeanDedieu      10.0
# 16  17     NIYONKURU Jeandedieu      10.0
# 17  18        NIYONKURU Olivier      10.0
# 18  19  NSENGIYAREMYE Frederick      10.0
# 19  20       UMUTONIWASE Denyse       8.0
# 20  21             UWASE Citecy       8.0
# ...

# %%
myinfo_data=pd.read_excel("C:\\Users\\PC\\Desktop\\MARKS FOR II TERM ALL CLASSES.xlsx")

# %%
myinfo_data.shape
# Out:
# (33, 3)

# %%
myinfo_data.isna().sum()
# Out:
# N0           0
# NAMES       10
# QUIZ1/10    10
# dtype: int64

# %%
from ydata_profiling  import ProfileReport
profile=ProfileReport(myinfo_data)
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;YData Profiling vv4.14.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2025-04-21 21:51:55.824692&quot;&gt;&lt;title&gt;YData Profiling Report&lt;/title&gt;&lt;style&gt;
# @charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...

# %%
myinfo_data.columns
# Out:
# Index(['N0', 'NAMES', 'QUIZ1/10'], dtype='object')

# %%
import numpy as np

# %%
6+9
# Out:
# 15
